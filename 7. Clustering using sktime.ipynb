# %%
from sklearn.model_selection import train_test_split
from sktime.clustering.k_means import TimeSeriesKMeans
from sktime.clustering.utils.plotting._plot_partitions import plot_cluster_algorithm
from sktime.datasets import load_arrow_head

# %%
X, y = load_arrow_head(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((158, 1), (53, 1), (158,), (53,))

# %%
X_train
# Out:
#                                                  dim_0
# 121  0     -2.015708
# 1     -2.000595
# 2     -1.99105...
# 71   0     -1.970077
# 1     -2.005721
# 2     -2.02161...
# 0    0     -1.963009
# 1     -1.957825
# 2     -1.95614...
# 59   0     -1.859725
# 1     -1.851661
# 2     -1.80027...
# 126  0     -2.096304
# 1     -2.076308
# 2     -2.05748...
# ..                                                 ...
# 26   0     -2.255120
# 1     -2.233663
# 2     -2.22919...
# 90   0     -1.985143
# 1     -1.984748
# 2     -1.96563...
# 199  0     -1.688975
# 1     -1.699415
# 2     -1.65249...
# 137  0     -1.764552
# 1     -1.741547
# 2     -1.71897...
# 16   0     -2.053743
# 1     -2.036852
# 2     -2.03303...
#
# [158 rows x 1 columns]

# %%
k_means = TimeSeriesKMeans(n_clusters=5, init_algorithm="forgy", metric="dtw")

# %%
k_means.fit(X_train)
# Out:
# TimeSeriesKMeans(init_algorithm='forgy', n_clusters=5)

# %%
plot_cluster_algorithm(k_means, X_test, k_means.n_clusters)

# %%
k_means.predict(X_test)
# Out:
# array([2, 0, 1, 1, 0, 0, 2, 4, 1, 0, 2, 2, 4, 4, 0, 2, 1, 1, 0, 1, 4, 0,
#        1, 4, 2, 0, 0, 1, 4, 4, 2, 0, 0, 0, 2, 1, 2, 3, 1, 0, 2, 4, 2, 2,
#        0, 3, 2, 0, 0, 0, 0, 1, 2], dtype=int64)
